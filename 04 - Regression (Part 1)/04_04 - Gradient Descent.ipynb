# %% [markdown]
# # 04.04 - Gradient Descent

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('DbeIqrwb_dE', width=1280, height=720)

# %%
YouTubeVideo('3Kb0QS6z7WA', width=1280, height=720)

# %%
YouTubeVideo('E-I2DNVzQLg', width=1280, height=720)

# %%
YouTubeVideo('VVDHU_TWwUg', width=1280, height=720)

# %%
YouTubeVideo('YAJ5XBwlN4o', width=1280, height=720)
